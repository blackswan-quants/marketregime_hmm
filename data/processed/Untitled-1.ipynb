# %%
import pandas as pd
df = pd.read_parquet("features_dataset.parquet")
df.to_csv("gem.csv")

# %%
df = pd.read_parquet("market_features.parquet")
df
# Out:
#             spx_close  vix_close        R1        R2        M1        M2  \
# date
# 2024-12-31     586.01  17.350000 -0.003781 -0.025757 -0.030635  0.028104
# 2025-01-01     586.01  17.350000  0.000000 -0.025757 -0.000495  0.016049
# 2025-01-02     584.58  17.930000 -0.002443 -0.028117 -0.002631 -0.010990
# 2025-01-03     591.87  16.129999  0.012393 -0.005258  0.001691 -0.006198
# 2025-01-06     595.40  16.040001  0.005946  0.012115  0.001042 -0.004759
# ...               ...        ...       ...       ...       ...       ...
# 2025-11-03     685.18  16.370001  0.000000  0.000000  0.020510  0.054264
# 2025-11-04     685.18  16.370001  0.000000  0.000000  0.020510  0.057011
# 2025-11-05     685.18  16.370001  0.000000  0.000000  0.025708  0.054557
# 2025-11-06     685.18  16.370001  0.000000  0.000000  0.019974  0.052202
# 2025-11-07     685.18  16.370001  0.000000  0.000000  0.011848  0.049292
#
#                   V1        V2   V3_hl10   V3_hl20   S1_hl10   S1_hl20  \
# date
# ...
