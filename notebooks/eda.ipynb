# %%
import pandas as pd

df = pd.read_parquet(
    "C:/Users/emanu/OneDrive/Documenti/GitHub/marketregime_hmm/data/processed/cross_asset_features.parquet"
)

df.tail()          # ultime 5 righe
# oppure, ad es. ultime 20 righe:
df
# Out:
#             X1_corr_42  X1_corr_ewm_hl10  X1_corr_ewm_hl20  X2_beta_42  \
# date
# 2024-11-01         NaN               NaN               NaN         NaN
# 2024-11-04         NaN               NaN               NaN         NaN
# 2024-11-05         NaN         -1.000000         -1.000000         NaN
# 2024-11-06         NaN         -0.965439         -0.966052         NaN
# 2024-11-07         NaN         -0.932909         -0.935520         NaN
# ...                ...               ...               ...         ...
# 2025-10-21   -0.104833         -0.454473         -0.238304   -0.114851
# 2025-10-22   -0.121474         -0.433946         -0.232448   -0.135391
# 2025-10-23   -0.198181         -0.458749         -0.252255   -0.208293
# 2025-10-24   -0.215875         -0.454180         -0.251664   -0.229382
# 2025-10-27   -0.195061         -0.392606         -0.225217   -0.213158
#
#             X2_beta_63  X2_beta_ewm_hl10  X2_beta_ewm_hl20  X3_mom_diff_42  \
# date
# ...
